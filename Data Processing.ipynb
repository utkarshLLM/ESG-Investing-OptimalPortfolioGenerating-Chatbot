# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Price_risk_return_ieor4511.xlsx')

# %%
names_equity = df.loc[3:, 'EQY_FUND_CRNCY']

# %%
names_equity
# Out:
# 3                                          MMM US Equity
# 4                                          ABT US Equity
# 5                                         ABBV US Equity
# 6                                          ACN US Equity
# 7                                         ADBE US Equity
#                              ...
# 503                                        ZBH US Equity
# 504                                       ZION US Equity
# 505                                        ZTS US Equity
# 506                                                  NaN
# 507    The BLOOMBERG PROFESSIONAL service, BLOOMBERG ...
# Name: EQY_FUND_CRNCY, Length: 505, dtype: object

# %%
df
# Out:
#                                         EQY_FUND_CRNCY  \
# 0                                                  LCL
# 1                                               Ticker
# 2                                None (503 securities)
# 3                                        MMM US Equity
# 4                                        ABT US Equity
# ..                                                 ...
# 503                                      ZBH US Equity
# 504                                     ZION US Equity
# 505                                      ZTS US Equity
# 506                                                NaN
# 507  The BLOOMBERG PROFESSIONAL service, BLOOMBERG ...
#
#                       REL_INDEX FA_ADJUSTED  Unnamed: 3  Unnamed: 4  \
# 0                           NaN         NaN         NaN         NaN
# 1                          Name   Price:M-3   Price:M-6   Price:Y-1
# 2                           NaN         NaN         NaN         NaN
# ...

# %%
df = df.drop([0, 2])

# %%
df
# Out:
#                                         EQY_FUND_CRNCY  \
# 1                                               Ticker
# 3                                        MMM US Equity
# 4                                        ABT US Equity
# 5                                       ABBV US Equity
# 6                                        ACN US Equity
# ..                                                 ...
# 503                                      ZBH US Equity
# 504                                     ZION US Equity
# 505                                      ZTS US Equity
# 506                                                NaN
# 507  The BLOOMBERG PROFESSIONAL service, BLOOMBERG ...
#
#                       REL_INDEX FA_ADJUSTED  Unnamed: 3  Unnamed: 4  \
# 1                          Name   Price:M-3   Price:M-6   Price:Y-1
# 3                         3M CO   91.699997  103.709999      112.93
# 4           ABBOTT LABORATORIES   93.550003  105.300003      108.07
# ...

# %%
l = df.iloc[1]

# %%
list_columns = df.iloc[0].values

# %%
df = df.drop([1])

# %%
df
# Out:
#                                         EQY_FUND_CRNCY  \
# 3                                        MMM US Equity
# 4                                        ABT US Equity
# 5                                       ABBV US Equity
# 6                                        ACN US Equity
# 7                                       ADBE US Equity
# ..                                                 ...
# 503                                      ZBH US Equity
# 504                                     ZION US Equity
# 505                                      ZTS US Equity
# 506                                                NaN
# 507  The BLOOMBERG PROFESSIONAL service, BLOOMBERG ...
#
#                       REL_INDEX FA_ADJUSTED  Unnamed: 3  Unnamed: 4  \
# 3                         3M CO   91.699997  103.709999      112.93
# 4           ABBOTT LABORATORIES   93.550003  105.300003      108.07
# 5                    ABBVIE INC  138.039993  150.770004  148.699997
# ...

# %%
len(l)
# Out:
# 15

# %%
to_be_replaced_cols = list(df.columns)

# %%
d = {}
i = 0
for col in to_be_replaced_cols:
    d[col] = list_columns[i]
    i += 1

# %%
d
# Out:
# {'EQY_FUND_CRNCY': 'Ticker',
#  'REL_INDEX': 'Name',
#  'FA_ADJUSTED': 'Price:M-3',
#  'Unnamed: 3': 'Price:M-6',
#  'Unnamed: 4': 'Price:Y-1',
#  'Unnamed: 5': 'YTD Tot Ret',
#  'Unnamed: 6': 'Total Return:Y-1',
#  'Unnamed: 7': 'Total Return:M-6',
#  'Unnamed: 8': 'Total Return:M-3',
#  'Unnamed: 9': 'Total Return:M-1',
#  'Unnamed: 10': 'Total Return:D-1',
#  'Unnamed: 11': 'Beta:D-1',
#  'Unnamed: 12': 'Beta:M-3',
#  'Unnamed: 13': 'Beta:M-6',
#  'Unnamed: 14': 'Beta:Y-1'}

# %%
df = df.rename(columns=d)

# %%
df
# Out:
#                                                 Ticker  \
# 3                                        MMM US Equity
# 4                                        ABT US Equity
# 5                                       ABBV US Equity
# 6                                        ACN US Equity
# 7                                       ADBE US Equity
# ..                                                 ...
# 503                                      ZBH US Equity
# 504                                     ZION US Equity
# 505                                      ZTS US Equity
# 506                                                NaN
# 507  The BLOOMBERG PROFESSIONAL service, BLOOMBERG ...
#
#                            Name   Price:M-3   Price:M-6   Price:Y-1  \
# 3                         3M CO   91.699997  103.709999      112.93
# 4           ABBOTT LABORATORIES   93.550003  105.300003      108.07
# 5                    ABBVIE INC  138.039993  150.770004  148.699997
# ...

# %%
df_esg = pd.read_excel('esg_rank_ieor4511.xlsx')
df_esg
# Out:
#          Start Date  2024-01-01 00:00:00           Unnamed: 2  \
# 0          End Date                  NaN                  NaN
# 1               NaN                  NaN                  NaN
# 2               NaN                Dates  2024-01-05 00:00:00
# 3       A UN Equity        SP_R_ESG_RANK                  NaN
# 4     AAL UW Equity        SP_R_ESG_RANK                  NaN
# ..              ...                  ...                  ...
# 504  ZION UW Equity        SP_R_ESG_RANK                  NaN
# 505   ZTS UN Equity        SP_R_ESG_RANK                  NaN
# 506             NaN                  NaN                  NaN
# 507  ZION UW Equity  S&P Global ESG Rank        SP_R_ESG_RANK
# 508   ZTS UN Equity  S&P Global ESG Rank        SP_R_ESG_RANK
#
#               Unnamed: 3 Unnamed: 4           Unnamed: 5 Unnamed: 6  \
# 0                    NaN        NaT                  NaN        NaT
# 1                    NaN        NaT                  NaN        NaT
# ...

# %%
df_esg = df_esg.drop([0, 1])

# %%
df_esg = df_esg.drop([2])

# %%
df_esg
# Out:
#          Start Date  2024-01-01 00:00:00     Unnamed: 2       Unnamed: 3  \
# 3       A UN Equity        SP_R_ESG_RANK            NaN              NaN
# 4     AAL UW Equity        SP_R_ESG_RANK            NaN              NaN
# 5    AAPL UW Equity        SP_R_ESG_RANK            NaN              NaN
# 6    ABBV UN Equity        SP_R_ESG_RANK            NaN              NaN
# 7    ABNB UW Equity        SP_R_ESG_RANK            NaN              NaN
# ..              ...                  ...            ...              ...
# 504  ZION UW Equity        SP_R_ESG_RANK            NaN              NaN
# 505   ZTS UN Equity        SP_R_ESG_RANK            NaN              NaN
# 506             NaN                  NaN            NaN              NaN
# 507  ZION UW Equity  S&P Global ESG Rank  SP_R_ESG_RANK  #N/A Start Date
# 508   ZTS UN Equity  S&P Global ESG Rank  SP_R_ESG_RANK  #N/A Start Date
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# ...

# %%
df_esg.drop(df_esg.columns.difference(['Start Date','Unnamed: 5']), 1, inplace=True)
# Out:
# /var/folders/g1/mwvmvwd500q1llzmnkpcvpnc0000gn/T/ipykernel_13380/4106014076.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_esg.drop(df_esg.columns.difference(['Start Date','Unnamed: 5']), 1, inplace=True)

# %%
df_esg.rename(columns={'Start Date':'Ticker', 'Unnamed: 5':'ESGnumeric'}, inplace=True)

# %%
df
# Out:
#                                                 Ticker  \
# 3                                        MMM US Equity
# 4                                        ABT US Equity
# 5                                       ABBV US Equity
# 6                                        ACN US Equity
# 7                                       ADBE US Equity
# ..                                                 ...
# 503                                      ZBH US Equity
# 504                                     ZION US Equity
# 505                                      ZTS US Equity
# 506                                                NaN
# 507  The BLOOMBERG PROFESSIONAL service, BLOOMBERG ...
#
#                            Name   Price:M-3   Price:M-6   Price:Y-1  \
# 3                         3M CO   91.699997  103.709999      112.93
# 4           ABBOTT LABORATORIES   93.550003  105.300003      108.07
# 5                    ABBVIE INC  138.039993  150.770004  148.699997
# ...

# %%
len(df['Ticker'].values), len(df_esg['Ticker'].values)
# Out:
# (505, 506)

# %%
np.equal(list(df['Ticker'].values), list(df_esg['Ticker'].values))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 np.equal(list(df['Ticker'].values), list(df_esg['Ticker'].values))
#
# ValueError: operands could not be broadcast together with shapes (505,) (506,)

# %%
df_esg[df_esg['Ticker']=='ABBV UN Equity']
# Out:
#            Ticker ESGnumeric
# 6  ABBV UN Equity        100

# %%
df.drop([506, 507], inplace=True)

# %%
df
# Out:
#              Ticker                          Name   Price:M-3   Price:M-6  \
# 3     MMM US Equity                         3M CO   91.699997  103.709999
# 4     ABT US Equity           ABBOTT LABORATORIES   93.550003  105.300003
# 5    ABBV US Equity                    ABBVIE INC  138.039993  150.770004
# 6     ACN US Equity            ACCENTURE PLC-CL A  314.220001  311.529999
# 7    ADBE US Equity                     ADOBE INC   577.73999  513.780029
# ..              ...                           ...         ...         ...
# 501   YUM US Equity               YUM! BRANDS INC  124.709999  133.279999
# 502  ZBRA US Equity  ZEBRA TECHNOLOGIES CORP-CL A  202.520004  257.890015
# 503   ZBH US Equity    ZIMMER BIOMET HOLDINGS INC  104.120003  125.209999
# 504  ZION US Equity              ZIONS BANCORP NA   32.549999   37.400002
# 505   ZTS US Equity                    ZOETIS INC  170.630005  189.350006
#
#       Price:Y-1 YTD Tot Ret Total Return:Y-1 Total Return:M-6  \
# ...

# %%
df_esg
# Out:
#              Ticker ESGnumeric
# 3       A UN Equity         93
# 4     AAL UW Equity         93
# 5    AAPL UW Equity         65
# 6    ABBV UN Equity        100
# 7    ABNB UW Equity         42
# ..              ...        ...
# 504  ZION UW Equity         64
# 505   ZTS UN Equity         73
# 506             NaN        NaN
# 507  ZION UW Equity        NaN
# 508   ZTS UN Equity        NaN
#
# [506 rows x 2 columns]

# %%
df.to_excel('returns_companies.xlsx')
