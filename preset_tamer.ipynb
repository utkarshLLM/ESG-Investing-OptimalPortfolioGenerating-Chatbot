# %%
import pandas as pd

# %%
df = pd.read_csv('presets.csv')

# %%
row = df.iloc[0]
row
# Out:
# name                                                        AI Assistant
# content                You are a helpful assistant. Answer as concise...
# prompt                                   Where is the capital of France?
# model                                                      gpt-3.5-turbo
# max_tokens                                                        1000.0
# temperature                                                            1
# test_code                                                              0
# suggested_questions                                                    1
# streaming                                                              1
# Name: 0, dtype: object

# %%
row['name'] = 'Portfolio Optimizer'
# Out:
# /var/folders/g1/mwvmvwd500q1llzmnkpcvpnc0000gn/T/ipykernel_76887/37797516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row['name'] = 'Portfolio Optimizer'

# %%
row
# Out:
# name                                                 Portfolio Optimizer
# content                You are a helpful assistant. Answer as concise...
# prompt                                   Where is the capital of France?
# model                                                      gpt-3.5-turbo
# max_tokens                                                        1000.0
# temperature                                                            1
# test_code                                                              0
# suggested_questions                                                    1
# streaming                                                              1
# Name: 0, dtype: object

# %%
df
# Out:
#                               name  \
# 0                     AI Assistant
# 1                  Read a web page
# 2                Read a local file
# 3              Understand an image
# 4                Generate an image
# 5           English to MATLAB Code
# 6        English to Simulink Model
# 7                   Summarize Code
# 8        Explain Code Step by Step
# 9               Script to function
# 10           Write doc to function
# 11                         Fix Bug
# 12                Write Unit Tests
# 13                  Vectorize Code
# 14    Act as MATLAB Command Window
# 15              Sentiment Analysis
# 16              Contact Extraction
# 17          Extract table from PDF
# 18             Top 10 SciFi movies
# 19           San Francisco Weather
# 20           Boston Housing Prices
# 21                Boston Landmarks
# 22          Remove duplicate names
# 23  Email Domains to Company Names
# 24      Normalize University Names
#
#                                               content  \
# 0   You are a helpful assistant. Answer as concise...
# 1   You are a helpful assistant that can read a sm...
# 2   You are a helpful assistant that can read a sm...
# 3   You are a helpful assistant that can see an im...
# 4                                                 NaN
# 5   You are a helpful assistant that generates MAT...
# 6   You are a helpful assistant that creates Simul...
# 7   You are a friendly and helpful teaching assist...
# 8   You are a friendly and helpful teaching assist...
# 9   You are a friendly and helpful teaching assist...
# 10  You are a friendly and helpful teaching assist...
# 11  You are a friendly and helpful teaching assist...
# 12  You are a friendly and helpful teaching assist...
# 13  You are a friendly and helpful teaching assist...
# 14  You are a MATLAB interpreter. I will give you ...
# 15  You are a helpful assistant that helps data sc...
# 16  You are a helpful assistant that helps data sc...
# 17  You are a helpful assistant that helps data sc...
# 18  You are a helpful assistant that helps data sc...
# 19  You are a helpful assistant that helps data sc...
# 20  You are a helpful assistant that helps data sc...
# 21  You are a helpful assistant that helps data sc...
# 22  You are a helpful assistant that helps data sc...
# 23  You are a helpful assistant that helps data sc...
# 24  You are a helpful assistant that helps data sc...
#
#                                                prompt                 model  \
# 0                     Where is the capital of France?         gpt-3.5-turbo
# 1   What is this page about? https://www.mathworks...         gpt-3.5-turbo
# 2   Select a file using the paper clip icon on the...         gpt-3.5-turbo
# 3   What is in this image? https://www.mathworks.c...  gpt-4-vision-preview
# 4   Create a 3D avatar of a whimsical sushi on the...              dall-e-3
# 5   Define two random vectors x and y, fit a linea...         gpt-3.5-turbo
# 6   Model name: 'sine_multiplied' \nAdd Sine Wave ...         gpt-3.5-turbo
# 7   Summarize what the following code does. Code b...         gpt-3.5-turbo
# 8   Explain what the following code does. Code by ...         gpt-3.5-turbo
# 9   Convert the following script to a function, us...         gpt-3.5-turbo
# 10  Write useful docstring to this function derive...         gpt-3.5-turbo
# 11  Fix bug in the following MATLAB code\n\n```mat...         gpt-3.5-turbo
# 12  Write unit tests for this function, \n\n```mat...         gpt-3.5-turbo
# 13  Vectorize the following code without using for...         gpt-3.5-turbo
# 14                   ```matlab\nx = (1:10)*2\n```\n\n         gpt-3.5-turbo
# 15  Decide whether sentiment is positive, neutral,...         gpt-3.5-turbo
# 16  Extract the name and mailing address from this...         gpt-3.5-turbo
# 17  format the following PDF data into a table. St...         gpt-3.5-turbo
# 18  Create a  table of top 10 science fiction movi...         gpt-3.5-turbo
# 19  Create a table of weather temperatures for San...         gpt-3.5-turbo
# 20  Housing prices are correlated with size of the...         gpt-3.5-turbo
# 21  Create a markdown table of famous landmarks in...         gpt-3.5-turbo
# 22  Here is a list of names.\n\nJohn Smith\nWillia...         gpt-3.5-turbo
# 23  Identify legal company names based on the foll...         gpt-3.5-turbo
# 24  Normalize the list of university names below. ...         gpt-3.5-turbo
#
#     max_tokens  temperature  test_code  suggested_questions  streaming
# 0       1000.0            1          0                    1          1
# 1       1000.0            0          0                    1          1
# 2       1000.0            0          0                    1          1
# 3       1000.0            1          0                    0          0
# 4          inf            0          0                    0          0
# 5       1000.0            0          1                    1          1
# 6       1000.0            0          1                    1          1
# 7       1000.0            0          0                    1          1
# 8       1000.0            0          0                    1          1
# 9       1000.0            0          1                    1          1
# 10      1000.0            0          0                    1          1
# 11      1000.0            0          0                    1          1
# 12      1000.0            0          0                    1          1
# 13      1000.0            0          1                    1          1
# 14      1000.0            0          0                    1          1
# 15      1000.0            0          0                    1          1
# 16      1000.0            0          0                    1          1
# 17      1000.0            0          0                    1          1
# 18      1000.0            0          0                    1          1
# 19      1000.0            0          0                    1          1
# 20      1000.0            0          0                    1          1
# 21      1000.0            0          0                    1          1
# 22      1000.0            0          0                    1          1
# 23      1000.0            0          0                    1          1
# 24      1000.0            0          0                    1          1

# %%
type(row)
# Out:
# pandas.core.series.Series

# %%
df = df.append(row, ignore_index=True)
# Out:
# /var/folders/g1/mwvmvwd500q1llzmnkpcvpnc0000gn/T/ipykernel_76887/2395937557.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row, ignore_index=True)

# %%
df.loc[ 25, 'content'] = 'You are an assistant that is going to take in financial information from the the user, which is going to be used to create an optimal portfolio for them. This information gained from the user is going to include their risk-taking willingness, and extent of their sustainability preferences, i.e. Environmental, Social & Governance factors when investing. You are going to ask the user the following 13 questions numbered from 1 to 13 one-by-one to assess their risk tolerance: 1. In general, how would your best friend describe you as a risk taker?; 2. You are on a game show and can choose one of the following. Which of the following options would you choose? a. $1,000 in cash; b. A 50% chance at winning $5,000; c. A 25% chance at winning $10,000; d. A 5% chance at winning $100,000; 3. You have just finished saving for a “once-in-a-lifetime” vacation. Three weeks before you plan to leave, you lose your job. What would you do out of the following options: a. Cancel the vacation; b. Take a much more modest vacation; c. Go as scheduled, reasoning that you need the time to prepare for a job search; d. Extend your vacation, because this might be your last chance to go first-class; 4. If you unexpectedly received $20,000 to invest, what would you do? a. Deposit it in a bank account, money market account, or an insured CD; b. Invest it in safe high quality bonds or bond mutual funds; c. Invest it in stocks or stock mutual funds; 5. In terms of experience, how comfortable are you investing in stocks or stock mutual funds?; 6. When you think of the word “risk” what comes to mind first?; 7. Some experts are predicting prices of assets such as gold, jewels, collectibles, and real estate (hard assets) to increase in value; bond prices may fall, however, experts tend to agree that government bonds are relatively safe. Most of your investment assets are now in high interest government bonds. What would you do?; 8. Given the best and worst case returns of the four investment choices below, which would you prefer? a. $200 gain best case; $0 gain/loss worst case; b. $800 gain best case; $200 loss worst case; c. $2,600 gain best case; $800 loss worst case; d. $4,800 gain best case; $2,400 loss worst case; 9. In addition to whatever you own, you have been given $1,000. You are now asked to choose between: a. A sure gain of $500; b. A 50% chance to gain $1,000 and a 50% chance to gain nothing; 10. In addition to whatever you own, you have been given $2,000. You are now asked to choose between: a. A sure loss of $500; b. A 50% chance to lose $1,000 and a 50% chance to lose nothing; 11. Suppose a relative left you an inheritance of $100,000, stipulating in the will that you invest ALL the money in ONE of the following choices. Which of the following options would you select? a. A savings account or money market mutual fund; b. A mutual fund that owns stocks and bonds; c. A portfolio of 15 common stocks; d. Commodities like gold, silver, and oil; 12. If you had to invest $20,000, which of the following investment choices would you find most appealing? a. 60% in low-risk investments 30% in medium-risk investments 10% in high-risk investments; b. 30% in low-risk investments 40% in medium-risk investments 30% in high-risk investments; c. 10% in low-risk investments 40% in medium-risk investments 50% in high-risk investments; 13. Your trusted friend and neighbor, an experienced geologist, is putting together a group of investors to fund an exploratory gold mining venture. The venture could pay back 50 to 100 times the investment if successful. If the mine is a bust, the entire investment is worthless. Your friend estimates the chance of success is only 20%. If you had the money, how much would you invest? Tell us in terms of your monthly salary - eg: 1 month''s salary, 2 months'' etc. Out of these questions - some questions contain with them options as potential answer to those questions. For these the user will generally either respond with either the option letter i.e a or b or.., or else they are going to reply with some portion of the text contained/similar to one of the options. Based on this response, you have to figure out, which of the option the user has chosen. Then you would perform a sentiment analysis on how risky the response seems and record a quantiative value based on this risk-metric given by the range [1, 2, 3, 4], where 1 means least risky and 4 means the most risky. The value assigned should thus be an integer between 1 and 4 For the rest of the questions, i.e. the ones that do not have options contained within them, you should refer to this: for a question like "How much of a risk taker are you?", you have to do a sentiment analysis on the user''s response to determine how much riskiness does the user''s response indicate in context . This riskiness can be a general sentiment or in accordance to the finance, for example - "likes to invest in stocks" shows a risky inclination in terms of finance. According to the result of your analysis you''ll record one of these four values: [1, 2, 3, 4], where 1 is the least risky and 4 is the most risky. Try to make as precise delineations as possible. Do some nuanced analysis based on also the question asked, not just the user''s response. After those, we are going to present some ESG questions. You are going to ask the user the following 13 questions numbered from 14 to 26 one-by-one to assess their esg tolerance: 14. Will you be more inclined or indifferent in investing in a company that has more diverse boards? 15. Will you be more inclined or indifferent in investing in a company that regularly publishes sustainability reports?; 16. Will you be more inclined or indifferent in investing in a company that promotes the economic advancement of women and ethnic minorities? 17. Will you be more inclined or indifferent in investing in a company that gives generously to charitable causes? 18. Will you be more inclined or indifferent in investing in a company that demonstrates leadership in addressing climate change? 19. Will you be more inclined or indifferent in investing in a company that displays full disclosure of environmental risk and liability and are taking actions to minimize it?; 20. Will you be more inclined or indifferent in investing in a company that has strong pollution prevention programs?; 21. Will you be more inclined or indifferent in investing in a company that demonstrates diversity policies and fair treatment of employees?; 22. Will you be more inclined or indifferent in investing in a company that supports employee health and safety policies?; 23. Will you be more inclined or indifferent in investing in a company that bargains fairly with employees?; 24. Will you be more inclined or indifferent in investing in a company that demonstrates a solid commitment to the communities in which they operate?; 25. Will you be more inclined or indifferent in investing in a company that develops products that maintain quality control and respond quickly to correct problems in them?; 26. Will you be more inclined or indifferent in investing in a company that demonstrates integrity in their labeling and advertising? Each question 14 to 26 asked, describes a particular thing a company does, and thus for each question you would do a sentiment analysis on the user''s response to see if the user seems in favour of the activity mentioned in the question or not. If the user seems to agree, you are going to record the response as 1, and if the user does not seem in favour, record the response as 0, and if the user seems indifferent to it, you are going to record their response as 0.5. Once all the questions are asked and the responses for each of them recorded, you should end the conversation by thanking the user.'

# %%
df
# Out:
#                               name  \
# 0                     AI Assistant
# 1                  Read a web page
# 2                Read a local file
# 3              Understand an image
# 4                Generate an image
# 5           English to MATLAB Code
# 6        English to Simulink Model
# 7                   Summarize Code
# 8        Explain Code Step by Step
# 9               Script to function
# 10           Write doc to function
# 11                         Fix Bug
# 12                Write Unit Tests
# 13                  Vectorize Code
# 14    Act as MATLAB Command Window
# 15              Sentiment Analysis
# 16              Contact Extraction
# 17          Extract table from PDF
# 18             Top 10 SciFi movies
# 19           San Francisco Weather
# 20           Boston Housing Prices
# 21                Boston Landmarks
# 22          Remove duplicate names
# 23  Email Domains to Company Names
# 24      Normalize University Names
# 25             Portfolio Optimizer
#
#                                               content  \
# 0   You are a helpful assistant. Answer as concise...
# 1   You are a helpful assistant that can read a sm...
# 2   You are a helpful assistant that can read a sm...
# 3   You are a helpful assistant that can see an im...
# 4                                                 NaN
# 5   You are a helpful assistant that generates MAT...
# 6   You are a helpful assistant that creates Simul...
# 7   You are a friendly and helpful teaching assist...
# 8   You are a friendly and helpful teaching assist...
# 9   You are a friendly and helpful teaching assist...
# 10  You are a friendly and helpful teaching assist...
# 11  You are a friendly and helpful teaching assist...
# 12  You are a friendly and helpful teaching assist...
# 13  You are a friendly and helpful teaching assist...
# 14  You are a MATLAB interpreter. I will give you ...
# 15  You are a helpful assistant that helps data sc...
# 16  You are a helpful assistant that helps data sc...
# 17  You are a helpful assistant that helps data sc...
# 18  You are a helpful assistant that helps data sc...
# 19  You are a helpful assistant that helps data sc...
# 20  You are a helpful assistant that helps data sc...
# 21  You are a helpful assistant that helps data sc...
# 22  You are a helpful assistant that helps data sc...
# 23  You are a helpful assistant that helps data sc...
# 24  You are a helpful assistant that helps data sc...
# 25  You are an assistant that is going to take in ...
#
#                                                prompt                 model  \
# 0                     Where is the capital of France?         gpt-3.5-turbo
# 1   What is this page about? https://www.mathworks...         gpt-3.5-turbo
# 2   Select a file using the paper clip icon on the...         gpt-3.5-turbo
# 3   What is in this image? https://www.mathworks.c...  gpt-4-vision-preview
# 4   Create a 3D avatar of a whimsical sushi on the...              dall-e-3
# 5   Define two random vectors x and y, fit a linea...         gpt-3.5-turbo
# 6   Model name: 'sine_multiplied' \nAdd Sine Wave ...         gpt-3.5-turbo
# 7   Summarize what the following code does. Code b...         gpt-3.5-turbo
# 8   Explain what the following code does. Code by ...         gpt-3.5-turbo
# 9   Convert the following script to a function, us...         gpt-3.5-turbo
# 10  Write useful docstring to this function derive...         gpt-3.5-turbo
# 11  Fix bug in the following MATLAB code\n\n```mat...         gpt-3.5-turbo
# 12  Write unit tests for this function, \n\n```mat...         gpt-3.5-turbo
# 13  Vectorize the following code without using for...         gpt-3.5-turbo
# 14                   ```matlab\nx = (1:10)*2\n```\n\n         gpt-3.5-turbo
# 15  Decide whether sentiment is positive, neutral,...         gpt-3.5-turbo
# 16  Extract the name and mailing address from this...         gpt-3.5-turbo
# 17  format the following PDF data into a table. St...         gpt-3.5-turbo
# 18  Create a  table of top 10 science fiction movi...         gpt-3.5-turbo
# 19  Create a table of weather temperatures for San...         gpt-3.5-turbo
# 20  Housing prices are correlated with size of the...         gpt-3.5-turbo
# 21  Create a markdown table of famous landmarks in...         gpt-3.5-turbo
# 22  Here is a list of names.\n\nJohn Smith\nWillia...         gpt-3.5-turbo
# 23  Identify legal company names based on the foll...         gpt-3.5-turbo
# 24  Normalize the list of university names below. ...         gpt-3.5-turbo
# 25                    Where is the capital of France?         gpt-3.5-turbo
#
#     max_tokens  temperature  test_code  suggested_questions  streaming
# 0       1000.0            1          0                    1          1
# 1       1000.0            0          0                    1          1
# 2       1000.0            0          0                    1          1
# 3       1000.0            1          0                    0          0
# 4          inf            0          0                    0          0
# 5       1000.0            0          1                    1          1
# 6       1000.0            0          1                    1          1
# 7       1000.0            0          0                    1          1
# 8       1000.0            0          0                    1          1
# 9       1000.0            0          1                    1          1
# 10      1000.0            0          0                    1          1
# 11      1000.0            0          0                    1          1
# 12      1000.0            0          0                    1          1
# 13      1000.0            0          1                    1          1
# 14      1000.0            0          0                    1          1
# 15      1000.0            0          0                    1          1
# 16      1000.0            0          0                    1          1
# 17      1000.0            0          0                    1          1
# 18      1000.0            0          0                    1          1
# 19      1000.0            0          0                    1          1
# 20      1000.0            0          0                    1          1
# 21      1000.0            0          0                    1          1
# 22      1000.0            0          0                    1          1
# 23      1000.0            0          0                    1          1
# 24      1000.0            0          0                    1          1
# 25      1000.0            1          0                    1          1

# %%
df.loc[25, 'prompt'] = 'Hey there!, we are going to optimize your portfolio!'

# %%
df.loc[25, 'suggested_questions'] = 0

# %%
df
# Out:
#                               name  \
# 0                     AI Assistant
# 1                  Read a web page
# 2                Read a local file
# 3              Understand an image
# 4                Generate an image
# 5           English to MATLAB Code
# 6        English to Simulink Model
# 7                   Summarize Code
# 8        Explain Code Step by Step
# 9               Script to function
# 10           Write doc to function
# 11                         Fix Bug
# 12                Write Unit Tests
# 13                  Vectorize Code
# 14    Act as MATLAB Command Window
# 15              Sentiment Analysis
# 16              Contact Extraction
# 17          Extract table from PDF
# 18             Top 10 SciFi movies
# 19           San Francisco Weather
# 20           Boston Housing Prices
# 21                Boston Landmarks
# 22          Remove duplicate names
# 23  Email Domains to Company Names
# 24      Normalize University Names
# 25             Portfolio Optimizer
#
#                                               content  \
# 0   You are a helpful assistant. Answer as concise...
# 1   You are a helpful assistant that can read a sm...
# 2   You are a helpful assistant that can read a sm...
# 3   You are a helpful assistant that can see an im...
# 4                                                 NaN
# 5   You are a helpful assistant that generates MAT...
# 6   You are a helpful assistant that creates Simul...
# 7   You are a friendly and helpful teaching assist...
# 8   You are a friendly and helpful teaching assist...
# 9   You are a friendly and helpful teaching assist...
# 10  You are a friendly and helpful teaching assist...
# 11  You are a friendly and helpful teaching assist...
# 12  You are a friendly and helpful teaching assist...
# 13  You are a friendly and helpful teaching assist...
# 14  You are a MATLAB interpreter. I will give you ...
# 15  You are a helpful assistant that helps data sc...
# 16  You are a helpful assistant that helps data sc...
# 17  You are a helpful assistant that helps data sc...
# 18  You are a helpful assistant that helps data sc...
# 19  You are a helpful assistant that helps data sc...
# 20  You are a helpful assistant that helps data sc...
# 21  You are a helpful assistant that helps data sc...
# 22  You are a helpful assistant that helps data sc...
# 23  You are a helpful assistant that helps data sc...
# 24  You are a helpful assistant that helps data sc...
# 25  You are an assistant that is going to take in ...
#
#                                                prompt                 model  \
# 0                     Where is the capital of France?         gpt-3.5-turbo
# 1   What is this page about? https://www.mathworks...         gpt-3.5-turbo
# 2   Select a file using the paper clip icon on the...         gpt-3.5-turbo
# 3   What is in this image? https://www.mathworks.c...  gpt-4-vision-preview
# 4   Create a 3D avatar of a whimsical sushi on the...              dall-e-3
# 5   Define two random vectors x and y, fit a linea...         gpt-3.5-turbo
# 6   Model name: 'sine_multiplied' \nAdd Sine Wave ...         gpt-3.5-turbo
# 7   Summarize what the following code does. Code b...         gpt-3.5-turbo
# 8   Explain what the following code does. Code by ...         gpt-3.5-turbo
# 9   Convert the following script to a function, us...         gpt-3.5-turbo
# 10  Write useful docstring to this function derive...         gpt-3.5-turbo
# 11  Fix bug in the following MATLAB code\n\n```mat...         gpt-3.5-turbo
# 12  Write unit tests for this function, \n\n```mat...         gpt-3.5-turbo
# 13  Vectorize the following code without using for...         gpt-3.5-turbo
# 14                   ```matlab\nx = (1:10)*2\n```\n\n         gpt-3.5-turbo
# 15  Decide whether sentiment is positive, neutral,...         gpt-3.5-turbo
# 16  Extract the name and mailing address from this...         gpt-3.5-turbo
# 17  format the following PDF data into a table. St...         gpt-3.5-turbo
# 18  Create a  table of top 10 science fiction movi...         gpt-3.5-turbo
# 19  Create a table of weather temperatures for San...         gpt-3.5-turbo
# 20  Housing prices are correlated with size of the...         gpt-3.5-turbo
# 21  Create a markdown table of famous landmarks in...         gpt-3.5-turbo
# 22  Here is a list of names.\n\nJohn Smith\nWillia...         gpt-3.5-turbo
# 23  Identify legal company names based on the foll...         gpt-3.5-turbo
# 24  Normalize the list of university names below. ...         gpt-3.5-turbo
# 25  Hey there!, we are going to optimize your port...         gpt-3.5-turbo
#
#     max_tokens  temperature  test_code  suggested_questions  streaming
# 0       1000.0            1          0                    1          1
# 1       1000.0            0          0                    1          1
# 2       1000.0            0          0                    1          1
# 3       1000.0            1          0                    0          0
# 4          inf            0          0                    0          0
# 5       1000.0            0          1                    1          1
# 6       1000.0            0          1                    1          1
# 7       1000.0            0          0                    1          1
# 8       1000.0            0          0                    1          1
# 9       1000.0            0          1                    1          1
# 10      1000.0            0          0                    1          1
# 11      1000.0            0          0                    1          1
# 12      1000.0            0          0                    1          1
# 13      1000.0            0          1                    1          1
# 14      1000.0            0          0                    1          1
# 15      1000.0            0          0                    1          1
# 16      1000.0            0          0                    1          1
# 17      1000.0            0          0                    1          1
# 18      1000.0            0          0                    1          1
# 19      1000.0            0          0                    1          1
# 20      1000.0            0          0                    1          1
# 21      1000.0            0          0                    1          1
# 22      1000.0            0          0                    1          1
# 23      1000.0            0          0                    1          1
# 24      1000.0            0          0                    1          1
# 25      1000.0            1          0                    0          1

# %%
df.to_csv('presets.csv')

# %%
df
# Out:
#                               name  \
# 0                     AI Assistant
# 1                  Read a web page
# 2                Read a local file
# 3              Understand an image
# 4                Generate an image
# 5           English to MATLAB Code
# 6        English to Simulink Model
# 7                   Summarize Code
# 8        Explain Code Step by Step
# 9               Script to function
# 10           Write doc to function
# 11                         Fix Bug
# 12                Write Unit Tests
# 13                  Vectorize Code
# 14    Act as MATLAB Command Window
# 15              Sentiment Analysis
# 16              Contact Extraction
# 17          Extract table from PDF
# 18             Top 10 SciFi movies
# 19           San Francisco Weather
# 20           Boston Housing Prices
# 21                Boston Landmarks
# 22          Remove duplicate names
# 23  Email Domains to Company Names
# 24      Normalize University Names
# 25             Portfolio Optimizer
#
#                                               content  \
# 0   You are a helpful assistant. Answer as concise...
# 1   You are a helpful assistant that can read a sm...
# 2   You are a helpful assistant that can read a sm...
# 3   You are a helpful assistant that can see an im...
# 4                                                 NaN
# 5   You are a helpful assistant that generates MAT...
# 6   You are a helpful assistant that creates Simul...
# 7   You are a friendly and helpful teaching assist...
# 8   You are a friendly and helpful teaching assist...
# 9   You are a friendly and helpful teaching assist...
# 10  You are a friendly and helpful teaching assist...
# 11  You are a friendly and helpful teaching assist...
# 12  You are a friendly and helpful teaching assist...
# 13  You are a friendly and helpful teaching assist...
# 14  You are a MATLAB interpreter. I will give you ...
# 15  You are a helpful assistant that helps data sc...
# 16  You are a helpful assistant that helps data sc...
# 17  You are a helpful assistant that helps data sc...
# 18  You are a helpful assistant that helps data sc...
# 19  You are a helpful assistant that helps data sc...
# 20  You are a helpful assistant that helps data sc...
# 21  You are a helpful assistant that helps data sc...
# 22  You are a helpful assistant that helps data sc...
# 23  You are a helpful assistant that helps data sc...
# 24  You are a helpful assistant that helps data sc...
# 25  You are an assistant that is going to take in ...
#
#                                                prompt                 model  \
# 0                     Where is the capital of France?         gpt-3.5-turbo
# 1   What is this page about? https://www.mathworks...         gpt-3.5-turbo
# 2   Select a file using the paper clip icon on the...         gpt-3.5-turbo
# 3   What is in this image? https://www.mathworks.c...  gpt-4-vision-preview
# 4   Create a 3D avatar of a whimsical sushi on the...              dall-e-3
# 5   Define two random vectors x and y, fit a linea...         gpt-3.5-turbo
# 6   Model name: 'sine_multiplied' \nAdd Sine Wave ...         gpt-3.5-turbo
# 7   Summarize what the following code does. Code b...         gpt-3.5-turbo
# 8   Explain what the following code does. Code by ...         gpt-3.5-turbo
# 9   Convert the following script to a function, us...         gpt-3.5-turbo
# 10  Write useful docstring to this function derive...         gpt-3.5-turbo
# 11  Fix bug in the following MATLAB code\n\n```mat...         gpt-3.5-turbo
# 12  Write unit tests for this function, \n\n```mat...         gpt-3.5-turbo
# 13  Vectorize the following code without using for...         gpt-3.5-turbo
# 14                   ```matlab\nx = (1:10)*2\n```\n\n         gpt-3.5-turbo
# 15  Decide whether sentiment is positive, neutral,...         gpt-3.5-turbo
# 16  Extract the name and mailing address from this...         gpt-3.5-turbo
# 17  format the following PDF data into a table. St...         gpt-3.5-turbo
# 18  Create a  table of top 10 science fiction movi...         gpt-3.5-turbo
# 19  Create a table of weather temperatures for San...         gpt-3.5-turbo
# 20  Housing prices are correlated with size of the...         gpt-3.5-turbo
# 21  Create a markdown table of famous landmarks in...         gpt-3.5-turbo
# 22  Here is a list of names.\n\nJohn Smith\nWillia...         gpt-3.5-turbo
# 23  Identify legal company names based on the foll...         gpt-3.5-turbo
# 24  Normalize the list of university names below. ...         gpt-3.5-turbo
# 25  Hey there!, we are going to optimize your port...         gpt-3.5-turbo
#
#     max_tokens  temperature  test_code  suggested_questions  streaming
# 0       1000.0            1          0                    1          1
# 1       1000.0            0          0                    1          1
# 2       1000.0            0          0                    1          1
# 3       1000.0            1          0                    0          0
# 4          inf            0          0                    0          0
# 5       1000.0            0          1                    1          1
# 6       1000.0            0          1                    1          1
# 7       1000.0            0          0                    1          1
# 8       1000.0            0          0                    1          1
# 9       1000.0            0          1                    1          1
# 10      1000.0            0          0                    1          1
# 11      1000.0            0          0                    1          1
# 12      1000.0            0          0                    1          1
# 13      1000.0            0          1                    1          1
# 14      1000.0            0          0                    1          1
# 15      1000.0            0          0                    1          1
# 16      1000.0            0          0                    1          1
# 17      1000.0            0          0                    1          1
# 18      1000.0            0          0                    1          1
# 19      1000.0            0          0                    1          1
# 20      1000.0            0          0                    1          1
# 21      1000.0            0          0                    1          1
# 22      1000.0            0          0                    1          1
# 23      1000.0            0          0                    1          1
# 24      1000.0            0          0                    1          1
# 25      1000.0            1          0                    0          1
