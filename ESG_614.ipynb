# %%
import pandas as pd

# %%
df = pd.read_excel('616 price data.xlsx', index_col=0)

# %%
df
# Out:
#                      A        AAL         AAP        AAPL        ABBV  \
# 2014-01-02   36.933754  23.907925   99.924667   17.296654   34.181690
# 2014-01-03   37.400269  25.020357  102.783798   16.916718   34.392124
# 2014-01-06   37.216293  25.482304  101.800400   17.008968   33.136124
# 2014-01-07   37.748520  25.369171  103.056961   16.887325   33.201881
# 2014-01-08   38.366169  26.047947  102.255707   16.994270   33.116386
# ...                ...        ...         ...         ...         ...
# 2024-03-22  147.449997  14.820000   85.760002  172.279999  178.449997
# 2024-03-25  145.559998  14.920000   84.250000  170.850006  178.529999
# 2024-03-26  144.410004  14.920000   84.250000  169.710007  179.190002
# 2024-03-27  147.369995  15.300000   85.320000  173.309998  180.350006
# 2024-03-28  145.509995  15.350000   85.089996  171.479996  182.100006
#
#                  ABMD        ABNB         ABT       ACGL         ACN  ...  \
# ...

# %%
cols = list( df.columns )

# %%
cols
# Out:
# ['A',
#  'AAL',
#  'AAP',
#  'AAPL',
#  'ABBV',
#  'ABMD',
#  'ABNB',
#  'ABT',
#  'ACGL',
#  'ACN',
#  'ADBE',
#  'ADI',
#  'ADM',
#  'ADP',
#  'ADSK',
#  'ADT',
#  'AEE',
#  'AEP',
#  'AES',
#  'AET',
#  'AFL',
#  'AIG',
#  'AIV',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'ALB',
#  'ALGN',
#  'ALK',
#  'ALL',
#  'ALLE',
#  'ALTR',
#  'AMAT',
#  'AMCR',
#  'AMD',
#  'AME',
#  'AMG',
#  'AMGN',
#  'AMP',
#  'AMT',
#  'AMZN',
#  'AN',
#  'ANDV',
#  'ANET',
#  'ANSS',
#  'AON',
#  'AOS',
#  'APA',
#  'APD',
#  'APH',
#  'APTV',
#  'ARE',
#  'ATI',
#  'ATO',
#  'AVB',
#  'AVGO',
#  'AVY',
#  'AWK',
#  'AXON',
#  'AXP',
#  'AYI',
#  'AZO',
#  'BA',
#  'BAC',
#  'BALL',
#  'BAX',
#  'BBWI',
#  'BBY',
#  'BDX',
#  'BEAM',
#  'BEN',
#  'BG',
#  'BHF',
#  'BIIB',
#  'BIO',
#  'BK',
#  'BKNG',
#  'BKR',
#  'BLDR',
#  'BLK',
#  'BMS',
#  'BMY',
#  'BR',
#  'BRO',
#  'BSX',
#  'BWA',
#  'BX',
#  'BXP',
#  'C',
#  'CA',
#  'CAG',
#  'CAH',
#  'CARR',
#  'CAT',
#  'CB',
#  'CBOE',
#  'CBRE',
#  'CCE',
# ...

# %%
esg_numeric = pd.read_csv('esg_2013to2023_numeric.csv', index_col=0)

# %%
## No 'FOX' and 'MSCI' in esg data
cols.remove('FOX')

cols.remove('MSCI')

# %%
esg_numeric = esg_numeric[cols]

# %%
df
# Out:
#                      A        AAL         AAP        AAPL        ABBV  \
# 2014-01-02   36.933754  23.907925   99.924667   17.296654   34.181690
# 2014-01-03   37.400269  25.020357  102.783798   16.916718   34.392124
# 2014-01-06   37.216293  25.482304  101.800400   17.008968   33.136124
# 2014-01-07   37.748520  25.369171  103.056961   16.887325   33.201881
# 2014-01-08   38.366169  26.047947  102.255707   16.994270   33.116386
# ...                ...        ...         ...         ...         ...
# 2024-03-22  147.449997  14.820000   85.760002  172.279999  178.449997
# 2024-03-25  145.559998  14.920000   84.250000  170.850006  178.529999
# 2024-03-26  144.410004  14.920000   84.250000  169.710007  179.190002
# 2024-03-27  147.369995  15.300000   85.320000  173.309998  180.350006
# 2024-03-28  145.509995  15.350000   85.089996  171.479996  182.100006
#
#                  ABMD        ABNB         ABT       ACGL         ACN  ...  \
# ...

# %%
esg_numeric.index = pd.to_datetime(esg_numeric.index)

# %%
esg_numeric
# Out:
#             A  AAL  AAP  AAPL  ABBV  ABMD  ABNB  ABT  ACGL  ACN  ...  XEL  \
# Date                                                             ...
# 2013-01-01  7  NaN    2     5   NaN   3.0   NaN    2   NaN  NaN  ...    3
# 2013-02-01  7  NaN    2     5   2.0   3.0   NaN    2   NaN  NaN  ...    3
# 2013-03-01  7  NaN    2     5   2.0   3.0   NaN    2   NaN  NaN  ...    3
# 2013-04-09  7  NaN    2     5   2.0   3.0   NaN    2   NaN  NaN  ...    3
# 2013-05-01  7  NaN    2     5   2.0   3.0   NaN    2   NaN  NaN  ...    3
# ...        ..  ...  ...   ...   ...   ...   ...  ...   ...  ...  ...  ...
# 2023-08-01  6  3.0    5     4   4.0   NaN   3.0    5   NaN  NaN  ...    7
# 2023-09-01  6  3.0    5     4   4.0   NaN   3.0    4   NaN  NaN  ...    7
# 2023-10-01  6  3.0    5     4   4.0   NaN   3.0    4   NaN  NaN  ...    7
# 2023-11-01  6  3.0    5     4   4.0   NaN   3.0    4   NaN  NaN  ...    6
# 2023-12-01  6  3.0    5     4   4.0   NaN   3.0    4   NaN  NaN  ...    6
#
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2014-01-02', '2014-01-03', '2014-01-06', '2014-01-07',
#                '2014-01-08', '2014-01-09', '2014-01-10', '2014-01-13',
#                '2014-01-14', '2014-01-15',
#                ...
#                '2024-03-15', '2024-03-18', '2024-03-19', '2024-03-20',
#                '2024-03-21', '2024-03-22', '2024-03-25', '2024-03-26',
#                '2024-03-27', '2024-03-28'],
#               dtype='datetime64[ns]', length=2577, freq=None)

# %%
esg_numeric.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-02-01', '2013-03-01', '2013-04-09',
#                '2013-05-01', '2013-06-01', '2013-07-01', '2013-08-01',
#                '2013-09-01', '2013-10-01',
#                ...
#                '2023-03-01', '2023-04-01', '2023-05-01', '2023-06-01',
#                '2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01'],
#               dtype='datetime64[ns]', name='Date', length=132, freq=None)

# %%
esg_numeric.to_excel('esg_2013to2023_numeric_614.xlsx', index=True)

# %%
df[cols]
# Out:
#                      A        AAL         AAP        AAPL        ABBV  \
# 2014-01-02   36.933754  23.907925   99.924667   17.296654   34.181690
# 2014-01-03   37.400269  25.020357  102.783798   16.916718   34.392124
# 2014-01-06   37.216293  25.482304  101.800400   17.008968   33.136124
# 2014-01-07   37.748520  25.369171  103.056961   16.887325   33.201881
# 2014-01-08   38.366169  26.047947  102.255707   16.994270   33.116386
# ...                ...        ...         ...         ...         ...
# 2024-03-22  147.449997  14.820000   85.760002  172.279999  178.449997
# 2024-03-25  145.559998  14.920000   84.250000  170.850006  178.529999
# 2024-03-26  144.410004  14.920000   84.250000  169.710007  179.190002
# 2024-03-27  147.369995  15.300000   85.320000  173.309998  180.350006
# 2024-03-28  145.509995  15.350000   85.089996  171.479996  182.100006
#
#                  ABMD        ABNB         ABT       ACGL         ACN  ...  \
# ...

# %%
df = df[cols]

# %%
df
# Out:
#                      A        AAL         AAP        AAPL        ABBV  \
# 2014-01-02   36.933754  23.907925   99.924667   17.296654   34.181690
# 2014-01-03   37.400269  25.020357  102.783798   16.916718   34.392124
# 2014-01-06   37.216293  25.482304  101.800400   17.008968   33.136124
# 2014-01-07   37.748520  25.369171  103.056961   16.887325   33.201881
# 2014-01-08   38.366169  26.047947  102.255707   16.994270   33.116386
# ...                ...        ...         ...         ...         ...
# 2024-03-22  147.449997  14.820000   85.760002  172.279999  178.449997
# 2024-03-25  145.559998  14.920000   84.250000  170.850006  178.529999
# 2024-03-26  144.410004  14.920000   84.250000  169.710007  179.190002
# 2024-03-27  147.369995  15.300000   85.320000  173.309998  180.350006
# 2024-03-28  145.509995  15.350000   85.089996  171.479996  182.100006
#
#                  ABMD        ABNB         ABT       ACGL         ACN  ...  \
# ...

# %%
df['Date'] = df.index
# Out:
# /var/folders/g1/mwvmvwd500q1llzmnkpcvpnc0000gn/T/ipykernel_25487/45558202.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df.index

# %%
df
# Out:
#                      A        AAL         AAP        AAPL        ABBV  \
# 2014-01-02   36.933754  23.907925   99.924667   17.296654   34.181690
# 2014-01-03   37.400269  25.020357  102.783798   16.916718   34.392124
# 2014-01-06   37.216293  25.482304  101.800400   17.008968   33.136124
# 2014-01-07   37.748520  25.369171  103.056961   16.887325   33.201881
# 2014-01-08   38.366169  26.047947  102.255707   16.994270   33.116386
# ...                ...        ...         ...         ...         ...
# 2024-03-22  147.449997  14.820000   85.760002  172.279999  178.449997
# 2024-03-25  145.559998  14.920000   84.250000  170.850006  178.529999
# 2024-03-26  144.410004  14.920000   84.250000  169.710007  179.190002
# 2024-03-27  147.369995  15.300000   85.320000  173.309998  180.350006
# 2024-03-28  145.509995  15.350000   85.089996  171.479996  182.100006
#
#                  ABMD        ABNB         ABT       ACGL         ACN  ...  \
# ...

# %%
cols.append( 'Date' )

# %%
cols = cols[-1:] + cols[:-1]

# %%
cols
# Out:
# ['Date',
#  'A',
#  'AAL',
#  'AAP',
#  'AAPL',
#  'ABBV',
#  'ABMD',
#  'ABNB',
#  'ABT',
#  'ACGL',
#  'ACN',
#  'ADBE',
#  'ADI',
#  'ADM',
#  'ADP',
#  'ADSK',
#  'ADT',
#  'AEE',
#  'AEP',
#  'AES',
#  'AET',
#  'AFL',
#  'AIG',
#  'AIV',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'ALB',
#  'ALGN',
#  'ALK',
#  'ALL',
#  'ALLE',
#  'ALTR',
#  'AMAT',
#  'AMCR',
#  'AMD',
#  'AME',
#  'AMG',
#  'AMGN',
#  'AMP',
#  'AMT',
#  'AMZN',
#  'AN',
#  'ANDV',
#  'ANET',
#  'ANSS',
#  'AON',
#  'AOS',
#  'APA',
#  'APD',
#  'APH',
#  'APTV',
#  'ARE',
#  'ATI',
#  'ATO',
#  'AVB',
#  'AVGO',
#  'AVY',
#  'AWK',
#  'AXON',
#  'AXP',
#  'AYI',
#  'AZO',
#  'BA',
#  'BAC',
#  'BALL',
#  'BAX',
#  'BBWI',
#  'BBY',
#  'BDX',
#  'BEAM',
#  'BEN',
#  'BG',
#  'BHF',
#  'BIIB',
#  'BIO',
#  'BK',
#  'BKNG',
#  'BKR',
#  'BLDR',
#  'BLK',
#  'BMS',
#  'BMY',
#  'BR',
#  'BRO',
#  'BSX',
#  'BWA',
#  'BX',
#  'BXP',
#  'C',
#  'CA',
#  'CAG',
#  'CAH',
#  'CARR',
#  'CAT',
#  'CB',
#  'CBOE',
#  'CBRE',
# ...

# %%
# Reordering
df  = df[cols]

# %%
df
# Out:
#                  Date           A        AAL         AAP        AAPL  \
# 2014-01-02 2014-01-02   36.933754  23.907925   99.924667   17.296654
# 2014-01-03 2014-01-03   37.400269  25.020357  102.783798   16.916718
# 2014-01-06 2014-01-06   37.216293  25.482304  101.800400   17.008968
# 2014-01-07 2014-01-07   37.748520  25.369171  103.056961   16.887325
# 2014-01-08 2014-01-08   38.366169  26.047947  102.255707   16.994270
# ...               ...         ...        ...         ...         ...
# 2024-03-22 2024-03-22  147.449997  14.820000   85.760002  172.279999
# 2024-03-25 2024-03-25  145.559998  14.920000   84.250000  170.850006
# 2024-03-26 2024-03-26  144.410004  14.920000   84.250000  169.710007
# 2024-03-27 2024-03-27  147.369995  15.300000   85.320000  173.309998
# 2024-03-28 2024-03-28  145.509995  15.350000   85.089996  171.479996
#
#                   ABBV       ABMD        ABNB         ABT       ACGL  ...  \
# ...

# %%
df.to_excel('614 price data.xlsx')

# %%
esg_numeric
# Out:
#             A  AAL  AAP  AAPL  ABBV  ABMD  ABNB  ABT  ACGL  ACN  ...  XEL  \
# Date                                                             ...
# 2013-01-01  7  NaN    2     5   NaN   3.0   NaN    2   NaN  NaN  ...    3
# 2013-02-01  7  NaN    2     5   2.0   3.0   NaN    2   NaN  NaN  ...    3
# 2013-03-01  7  NaN    2     5   2.0   3.0   NaN    2   NaN  NaN  ...    3
# 2013-04-09  7  NaN    2     5   2.0   3.0   NaN    2   NaN  NaN  ...    3
# 2013-05-01  7  NaN    2     5   2.0   3.0   NaN    2   NaN  NaN  ...    3
# ...        ..  ...  ...   ...   ...   ...   ...  ...   ...  ...  ...  ...
# 2023-08-01  6  3.0    5     4   4.0   NaN   3.0    5   NaN  NaN  ...    7
# 2023-09-01  6  3.0    5     4   4.0   NaN   3.0    4   NaN  NaN  ...    7
# 2023-10-01  6  3.0    5     4   4.0   NaN   3.0    4   NaN  NaN  ...    7
# 2023-11-01  6  3.0    5     4   4.0   NaN   3.0    4   NaN  NaN  ...    6
# 2023-12-01  6  3.0    5     4   4.0   NaN   3.0    4   NaN  NaN  ...    6
#
# ...

# %%
esg_numeric.iloc[-1]
# Out:
# A       6.0
# AAL     3.0
# AAP     5.0
# AAPL    4.0
# ABBV    4.0
#        ...
# YUM     4.0
# ZBH     6.0
# ZBRA    5.0
# ZION    4.0
# ZTS     7.0
# Name: 2023-12-01 00:00:00, Length: 614, dtype: float64
